# %%
# Стандартные библиотеки Python
import json
import os
import time
from datetime import datetime
from typing import List, Dict, Any

# Внешние библиотеки
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from IPython.display import clear_output

# Локальные модули
from board import Board, Move
from game import Game, NumpyEncoder
from mcts_agent import MCTS_Agent, MCTSNode
from model_manager import ModelManager
from random_network import RandomNetwork, PytorchAgentWrapper
from rl_agent import RLAgent
from noise import DirichletNoiseConfig
from train_data_handle import save_training_data

# %%
SAVE_DIR = "training_run_01"
os.makedirs(SAVE_DIR, exist_ok=True)

DATA_SAVE_DIR = "game_datasets"
os.makedirs(DATA_SAVE_DIR, exist_ok=True)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Используемое устройство: {DEVICE}")


# --- 0. НАСТРОЙКИ И ИНИЦИАЛИЗАЦИЯ ---
print("="*60)
print("НАСТРОЙКА ПАРАМЕТРОВ ОБУЧЕНИЯ")
print("="*60)

# Гиперпараметры
NUM_RES_BLOCKS = 15
NUM_SIMULATIONS = 400
MAX_MOVES_PER_GAME = 50
NUM_GAMES_TO_GENERATE = 1000
GAMES_BATCH = 100
TRAINING_EPOCHS = 20
BATCH_SIZE = 512
LEARNING_RATE = 0.001
TOURNAMENT_GAMES = 100
WIN_THRESHOLD = 0.70 # Новая модель должна выиграть >% игр
# Out:
# Используемое устройство: cuda
# ...
# НАСТРОЙКА ПАРАМЕТРОВ ОБУЧЕНИЯ
# ...

# %%
model_manager = ModelManager(
    RLAgent, 
    save_dir=SAVE_DIR, 
    device=DEVICE,
    NUM_RES_BLOCKS=NUM_RES_BLOCKS
)

# %%
def init_weights(model: nn.Module):
    """Применяет Kaiming и Xavier инициализацию к модели."""
    for m in model.modules():
        if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0)

# %%
def play_game_with_visualization(
    rl_agent: MCTS_Agent, 
    random_turns : int = 10, random_agent: MCTS_Agent = None, delay: float = 1.0, 
    max_moves: int = 300, extra_data: str = ""):
    """
    Запустить одну партию с визуализацией в Jupyter Notebook.
    
    Args:
        agent: MCTS агент для игры
        delay: Задержка между ходами в секундах (минимум 1.0)
        max_moves: Максимальное количество ходов (защита от зацикливания)
        
    Returns:
        game: Финальное состояние игры
    """
    # Создаем новую игру
    game = Game()
    move_count = 0
    
    print("=" * 60)
    print("НАЧАЛО ИГРЫ: MCTS Agent (Self-Play)")
    print(f"Симуляций MCTS на ход: {rl_agent.num_simulations}")
    print(f"Температура: {rl_agent.temperature}")
    print("=" * 60)
    time.sleep(2)
    
    best_node = None

    turn_index = 0
    
    # Игровой цикл
    while (not game.game_over) and (move_count < max_moves):
        clear_output(wait=True)

        
        
        # Отображаем текущее состояние
        print("=" * 60)
        print(f"ХОД {move_count + 1} | {extra_data}")
        print("=" * 60)
        game.print_board()
        print()
        


        if  not (random_agent is None) and turn_index < random_turns:
            agent = random_agent
        else:
            agent = rl_agent

        # Запускаем MCTS поиск
        print(f"🔍 MCTS запущен ({agent.num_simulations} симуляций)...")
        start_time = time.time()
        
        if best_node is None:
            move, policy, best_node = agent.search(game)
        else:
            move, policy, best_node = agent.search(game, best_node)

        turn_index += 1
        
        search_time = time.time() - start_time
        print(f"✅ MCTS завершен за {search_time:.2f} сек")
        print(f"📍 Выбран ход: {move}")
        
        current_state_tensor = game.get_network_input_pytorch(32)
        game.history.append({
            'state_tensor': current_state_tensor,
            'mcts_policy': policy,
            'player': game.current_player
        })
        
        # Применяем ход
        success = game.make_move(move)
        

        if not success:
            raise Exception(f"")
            print("❌ ОШИБКА: Ход не был применен!")
            break
        
        move_count += 1

        if delay - search_time > 0:
            time.sleep(delay - search_time)

    # Финальное состояние
    clear_output(wait=True)
    print("=" * 60)
    print(f"ИГРА ОКОНЧЕНА! {max_moves}")
    print("=" * 60)
    game.print_board()
    print()
    
    # Подсчет очков
    game.print_score()
    print()
    print(f"Всего ходов: {move_count}")
    
    if move_count >= max_moves:
        print(f"⚠️  Достигнут лимит ходов ({max_moves})")
    
    return game

# %%
def process_game_history(history: list, winner: int) -> list:
    """Добавляет к каждой записи в истории результат игры."""
    processed = []
    index = 0
    for turn_data in history:
        # Результат с точки зрения текущего игрока
        if turn_data['player'] == winner:
            value = 1.0
        elif winner is None: # Ничья
            value = 0.0
        else: # Проигрыш
            value = -1.0
            
        processed.append({
            'state_tensor': turn_data['state_tensor'],
            'mcts_policy': turn_data['mcts_policy'],
            'value': value,
            'turn' : index
        })
        index += 1
    return processed

# %%
# --- 1. НАЧАЛЬНАЯ ИНИЦИАЛИЗАЦИЯ МОДЕЛИ (выполняется один раз) ---
print("\n" + "="*60)
print("БЛОК 1: ИНИЦИАЛИЗАЦИЯ НАЧАЛЬНОЙ МОДЕЛИ")
print("="*60)

# Создаем и сохраняем "нулевую" модель
current_best_model_id = "agent_v0"
challenger_model = model_manager.create_new_model() # create_new_model уже вызывает init_weights

# Сохраняем чекпоинт с метаданными (пока без оптимизатора)
initial_metadata = {'games_played': 0, 'version': 0}
model_manager.save_checkpoint(challenger_model, None, initial_metadata, f"{current_best_model_id}.pth")

print(f"Начальная модель '{current_best_model_id}' создана и сохранена.")
# Out:
# ...
# БЛОК 1: ИНИЦИАЛИЗАЦИЯ НАЧАЛЬНОЙ МОДЕЛИ
# ...
# Creating a new model with random weights...
# Checkpoint saved to training_run_01\agent_v0.pth
# Начальная модель 'agent_v0' создана и сохранена.

# %%
#### print("\n" + "="*60)
print(f"БЛОК 2: ГЕНЕРАЦИЯ {NUM_GAMES_TO_GENERATE} ИГР")
print("="*60)
    
# Загружаем лучшую на данный момент модель
best_model = model_manager.load_model_weights(f"new_agent_0_3.pth")     
network = PytorchAgentWrapper(best_model, device=DEVICE)
agent_rl = MCTS_Agent(network, num_simulations=NUM_SIMULATIONS, temperature=1.0)


def generate_self_play_games(
    games_to_generate : int, games_batch: int, 
    rl_agent : MCTS_Agent, max_moves : int, 
    data_save_dir : str):
    
    random = RandomNetwork()    
    agent_random = MCTS_Agent(random, num_simulations=100, temperature=1.0)
    
    for k in range(int(games_to_generate / games_batch) if games_batch < games_to_generate else 1):    
        all_training_data = []
        start_time = time.time()
        for i in range(games_batch if games_batch < games_to_generate else games_to_generate):
            text = f"ИГРА {i+1 + k * games_batch}/{games_to_generate} | ПРОШЛО {time.time() - start_time}c."
            game_result = play_game_with_visualization(rl_agent=rl_agent, random_agent=agent_random, random_turns=0, delay=0, max_moves=max_moves, extra_data=text)
            
            # Обрабатываем историю, добавляя итоговый результат
            processed_history = process_game_history(game_result.history, game_result.get_winner())
            all_training_data.extend(processed_history)
    
            # --- Блок сохранения данных ---
            
        print(f"\nЭтап {k} сбора данных завершен. Собрано {len(all_training_data)} состояний.")
    
        if not save_training_data(save_dir=data_save_dir, training_data=all_training_data):
            print(f"\n❌ Ошибка при сохранении батча игр. Генерация остановлена.")
            break
# Out:
# ...
# ХОД 50 | ИГРА 601/1000 | ПРОШЛО 0.0c.
# ...
#  0|❎❎❎🔴❎❎❎
#  1|🔴❎❎❎❎❎❎
#  2|❎❎❎❎❎⚫🔴
#  3|❎❎❎❎❎⚫❎
#  4|❎❎❎❎❎⚫❎
#  5|❎🔴❎❎❎🔴❎
#  6|❎❎❎❎❎❎❎
#
# Текущий игрок: 🔴 БЕЛЫЕ
# Последовательных пасов: 1
#
# 🔍 MCTS запущен (400 симуляций)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 25
#      23 for i in range(GAMES_BATCH if GAMES_BATCH < NUM_GAMES_TO_GENERATE else NUM_GAMES_TO_GENERATE):
#      24     text = f"ИГРА {i+1 + k * GAMES_BATCH}/{NUM_GAMES_TO_GENERATE} | ПРОШЛО {time.time() - start_time}c."
# ---> 25     game_result = play_game_with_visualization(rl_agent=agent_rl, random_agent=agent_random, random_turns=0, delay=0, max_moves=MAX_MOVES_PER_GAME, extra_data=text)
#      27     # Обрабатываем историю, добавляя итоговый результат
#      28     processed_history = process_game_history(game_result.history, game_result.get_winner())
#
# ...

# %%
for i in range(50):
    print_board_heatmaps_for_move(
    move_index=i,
    history=0,
    states=all_training_data,
    thresholds=(5, 10, 15, 25, 50, 95),  # легко крутить границы
)            
    #0:5 5:10 10:15 15:25 25:50 40:95
    #🟢 🟡    🟠   🟤    🔴   🟣     🔵
    
    clear_output(wait=True)
    time.sleep(1)
# Out:
# Ход (turn) == 49
# Чёрные камни:
# 🟢🟢🟠🟢🟢🟠🟡
# 🟠🟢🟠🟠🟢🟡🟢
# 🟢🟡🟢🟢🟡🟠🟡
# 🟠🟡🟢🟢🟢🟢🟢
# 🟡🟠⚪🟢🟡🟢🟢
# 🟡🟤🟤🟠🟡🟤🟡
# 🟡🟤🟡🟢🟡🟤🟤
#
# Белые камни:
# 🟢🟡🟡🟢🟢🟡🟢
# 🟢🟡🟤🟡🟤🟠🟢
# 🟡🟠🟢🟢🟡🟤🟢
# 🟤🟡🟢⚪🟡🟠🟡
# 🟢🟠🟡🟢🟠🟢🟠
# 🟡🟡🟢⚪🟡🟠🟡
# 🟢🟢🟢⚪🟢🟢🟢

# %%
TRAINING_EPOCHS = 3
BATCH_SIZE = 512
LEARNING_RATE = 0.001

# --- 3. ОБУЧЕНИЕ МОДЕЛИ ---
print("\n" + "="*60)
print("БЛОК 3: ОБУЧЕНИЕ НОВОЙ МОДЕЛИ-ПРЕТЕНДЕНТА")
print("="*60)
current_best_model_id = 'agent_v0'
# Создаем новую модель-претендента на основе весов лучшей модели
challenger_model = model_manager.load_model_weights(f"{current_best_model_id}.pth")
optimizer = torch.optim.Adam(challenger_model.parameters(), lr=LEARNING_RATE, weight_decay=1e-4
)

# Обучаем (теперь все аргументы совпадают)
train_network(
    challenger_model,
    optimizer,
    all_training_data,
    epochs=TRAINING_EPOCHS,
    batch_size=BATCH_SIZE,
    device=DEVICE 
)

# Сохраняем модель-претендента
challenger_id = "new_agent_0_3"
challenger_metadata = {'parent_version': 0}
model_manager.save_checkpoint(challenger_model, optimizer, challenger_metadata, f"{challenger_id}.pth")
print(f"Новая модель-претендент '{challenger_id}' обучена и сохранена.")
# Out:
# ...
# БЛОК 3: ОБУЧЕНИЕ НОВОЙ МОДЕЛИ-ПРЕТЕНДЕНТА
# ...
# Model weights loaded from training_run_01\agent_v0.pth
# Начинаем обучение на 187965 примерах...
# Эпоха 1/3: Policy Loss = 1.8152, Value Loss = 0.7386
# Эпоха 2/3: Policy Loss = 1.7723, Value Loss = 0.7257
# Эпоха 3/3: Policy Loss = 1.7208, Value Loss = 0.7189
# Checkpoint saved to training_run_01\new_agent_0_3.pth
# Новая модель-претендент 'new_agent_0_3' обучена и сохранена.

# %%
def play_tournament_game(player1: MCTS_Agent, player2: MCTS_Agent, max_moves: int = 300, extra_text = ""):
    """
    Запускает одну быструю партию между двумя агентами без визуализации.

    Args:
        player1 (MCTS_Agent): Агент, играющий за Черных (ходит первым).
        player2 (MCTS_Agent): Агент, играющий за Белых.
        max_moves (int): Максимальное количество ходов для предотвращения зацикливания.

    Returns:
        Game: Объект с финальным состоянием игры.
    """
    # 1. Создание новой игры
    game = Game()
    move_count = 0
    
    # Игровой цикл
    while not game.game_over and move_count < max_moves:


        clear_output(wait=True)
        
        # Отображаем текущее состояние
        print("=" * 60)
        print(f"| ХОД {move_count + 1} | {extra_text} |")
        print("=" * 60)
        game.print_board()
        print()

        # 2. Выбор текущего агента в зависимости от цвета игрока
        if game.current_player == game.board.BLACK:
            current_agent = player1
        else:
            current_agent = player2

        # Запускаем MCTS поиск
        print(f"🔍 MCTS запущен ({current_agent.num_simulations} симуляций)...")
        start_time = time.time()
            
        # 3. Запуск MCTS поиска для текущего агента
        # Мы не сохраняем историю и политику, так как в турнире нас интересует только результат
        move, _, _ = current_agent.search(game)

        search_time = time.time() - start_time
        print(f"✅ MCTS завершен за {search_time:.2f} сек")
        print(f"📍 Выбран ход: {move}")

        
        # 4. Применение хода
        success = game.make_move(move)
        
        if not success:
            print(f"❌ ОШИБКА: Агент {game.current_player} сделал нелегальный ход {move}!")
            # В этом случае нужно присвоить победу оппоненту
            game.winner = game.get_opponent(game.current_player)
            game.game_over = True
            break # Прерываем игру
            
        move_count += 1
    
    # Если игра не завершилась по правилам (например, два паса),
    # но достигнут лимит ходов, победитель определяется по очкам.
    if not game.game_over:
        score = game.board.calculate_score()
        game.winner = score.get('winner')
        game.game_over = True
        
    return game

# %%
MAX_MOVES_PER_GAME = 50

# --- 4. ТУРНИР ---
print("\n" + "="*60)
print("БЛОК 4: ТУРНИР МЕЖДУ МОДЕЛЯМИ")
print("="*60)

# Агент "Претендент" (новая, только что обученная модель)
challenger_model = model_manager.load_model_weights(f"challenger_2_v3.pth")
challenger_network = PytorchAgentWrapper(challenger_model, device=DEVICE)
challenger_agent = MCTS_Agent(challenger_network, num_simulations=NUM_SIMULATIONS, temperature=0, noise_config=DirichletNoiseConfig.for_tournament()) # Температура 0 для детерминированной игры

best_model = model_manager.load_model_weights(f"agent_v0.pth")
best_network = PytorchAgentWrapper(best_model, device=DEVICE)
best_agent = MCTS_Agent(best_network, num_simulations=NUM_SIMULATIONS, temperature=0, noise_config=DirichletNoiseConfig.for_tournament())

wins_challenger = 0
wins_best = 0

for i in range(TOURNAMENT_GAMES):
    print(f"\n--- Турнирная игра {i+1}/{TOURNAMENT_GAMES} ---")
    
    # Чередуем, кто играет черными, чтобы исключить преимущество первого хода
    if i % 2 == 0:
        print("Претендент играет за Черных, Чемпион - за Белых.")
        game = play_tournament_game(challenger_agent, best_agent, max_moves=MAX_MOVES_PER_GAME, 
                                    extra_text = f"ИГРА {i+1}/{TOURNAMENT_GAMES} | ПРЕТЕНДЕНТ - ЧЕРНЫЕ | СЧЕТ - П{wins_challenger}/Ч{i - wins_challenger}")
        game.print_score()
        if game.get_winner() == game.board.BLACK:
            wins_challenger += 1
    else:
        print("Чемпион играет за Черных, Претендент - за Белых.")
        game = play_tournament_game(best_agent, challenger_agent, max_moves=MAX_MOVES_PER_GAME,
                                   extra_text = f"ИГРА {i+1}/{TOURNAMENT_GAMES} | ПРЕТЕНДЕНТ - БЕЛЫЕ | СЧЕТ - П{wins_challenger}/Ч{i - wins_challenger}")
        game.print_score()
        if game.get_winner() == game.board.WHITE:
            wins_challenger += 1


    
    wins_best = TOURNAMENT_GAMES - wins_challenger
    
    print(f"Победитель партии: {game.get_winner()}. Текущий счет Претендента: {wins_challenger}/{i+1}")


print(f"\nРезультаты турнира: Претендент {wins_challenger} - {wins_best} Чемпион")
